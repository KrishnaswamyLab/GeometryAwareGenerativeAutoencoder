# %%
import wandb
import sys
import matplotlib.pyplot as plt
import scprep
import pandas as pd
sys.path.append('../../dmae/src/')
# from diffusion import DiffusionModel
# from evaluate import get_results
from omegaconf import OmegaConf
# from main import load_data, make_model
import numpy as np
import os
import glob
import matplotlib.animation as animation
from matplotlib.animation import PillowWriter
import torch
from model2 import Autoencoder, Preprocessor, Discriminator
import magic
import torch
import pathlib
import copy
from procrustes import Procrustes
import pickle
import graphtools
import scanpy as sc
from plotly3d.plot import scatter
from tqdm import tqdm

# %%
wandb.login()
api = wandb.Api()

# %%
folder_path = '../../src/wandb/'
entity = "xingzhis"
project = "dmae"

# %%
# run_id = "n97585qb" # phate, 2
# run_id = "1sl5x72m" # phate, 4
run_id = "mlplvxp6" # phate, 8
# run_id = "rv82u4is" # heatgeo, 2
# run_id = "wd4qulvj" # heatgeo, 4
# run_id = "mlplvxp6" # heatgeo, 8
# run_id = "6t9c44vo" # heatgeo, 0.5
run = api.run(f"{entity}/{project}/{run_id}")
cfg = OmegaConf.create(run.config)
folder_list = glob.glob(f"{folder_path}*{run.id}*")
ckpt_files = glob.glob(f"{folder_list[0]}/files/*.ckpt")
ckpt_path = ckpt_files[0]
# data_path2 = os.path.join(cfg.data.root, cfg.data.name + cfg.data.filetype)
# data = np.load(data_path2, allow_pickle=True)

model = Autoencoder.load_from_checkpoint(ckpt_path)
data = np.load(f"data/{cfg.data.name}{cfg.data.filetype}", allow_pickle=True)

with torch.no_grad():
    model.eval()
    x = torch.tensor(data['data'], dtype=torch.float32, device=model.device)
    # x = torch.tensor(X, dtype=torch.float32, device=model.device)
    z = model.encoder(x)
    xh = model.decoder(torch.tensor(z))
    z = z.cpu().numpy()
    xh = xh.cpu().numpy()

# proc = Procrustes()
# p1, z1, di = proc.fit_transform(data['phate'], z)
z1 = z
# Out:
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/.conda_envs/geosink/lib/python3.11/site-packages/pytorch_lightning/utilities/parsing.py:269: UserWarning:
#
# Attribute 'preprocessor' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['preprocessor'])`.
#
# /tmp/ipykernel_3080807/1002965238.py:24: UserWarning:
#
# To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).

# %%
fig = plt.figure(figsize=(15, 15))

ax1 = fig.add_subplot(221)
scprep.plot.scatter2d(data['phate'], ax=ax1, title='Original PHATE')

ax2 = fig.add_subplot(222, projection='3d')
scprep.plot.scatter3d(z1, ax=ax2, title='Encoded Space')

ax3 = fig.add_subplot(223, projection='3d')
scprep.plot.scatter3d(data['data'], ax=ax3, title='Original Data')

ax4 = fig.add_subplot(224, projection='3d')
scprep.plot.scatter3d(xh, ax=ax4, title='Reconstructed Data')

plt.suptitle('Saddle-Uniform')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_3080807/1106821847.py:16: UserWarning:
#
# Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.

# %%
from geodesic import jacobian

# %%
param = lambda uv: torch.stack([uv[:,0], uv[:,1], uv[:,0]**2 - uv[:,1]**2], axis=1)

# %%
jac = jacobian(model.encoder, x)
jac_uv = jacobian(lambda uv: model.encoder(param(uv)), x[:,[0,1]])

# %%
U, S, Vh = torch.linalg.svd(jac, full_matrices=False)
U_uv, S_uv, Vh_uv = torch.linalg.svd(jac_uv, full_matrices=False)

# %%
S.shape
# Out:
# torch.Size([3000, 3])

# %%
vol_elem = S.prod(axis=1)
vol_elem_uv = S_uv.prod(axis=1)

# %%
def area_element(u, v):
    """
    Computes the area element (volume element for the surface) at each point.
    """
    # Compute the components of the first fundamental form
    E = 1 + (2 * u)**2
    F = (2 * u) * (-2 * v)
    G = 1 + (2 * v)**2
    # Compute the area element
    dA = np.sqrt(E * G - F**2)
    return dA

def area_element_torch(u, v):
    """
    Computes the area element (volume element for the surface) at each point.
    """
    # Compute the components of the first fundamental form
    E = 1 + (2 * u)**2
    F = (2 * u) * (-2 * v)
    G = 1 + (2 * v)**2
    # Compute the area element
    dA = torch.sqrt(E * G - F**2)
    return dA

# %%
vol_elem_analycial = area_element_torch(x[:, 0], x[:, 1])

# %%
vol_elem_analycial
# Out:
# tensor([3.0324, 4.6989, 3.6564,  ..., 2.7726, 1.4014, 2.0742])

# %%
plt.scatter((vol_elem).detach().numpy(), (vol_elem_analycial).detach().numpy())

# %%
plt.scatter((vol_elem_uv).detach().numpy(), (vol_elem_analycial).detach().numpy())

# %%
np.corrcoef(vol_elem_uv.detach().numpy(), vol_elem_analycial.detach().numpy())[0,1]
# Out:
# -0.5703182494718542

# %%
plt.scatter(torch.log(vol_elem_uv).detach().numpy(), torch.log(vol_elem_analycial).detach().numpy())

# %%
plt.scatter((vol_elem).detach().numpy(), (vol_elem_analycial).detach().numpy())

# %%
plt.scatter((vol_elem * vol_elem_analycial).detach().numpy(), (vol_elem_analycial).detach().numpy())

# %%
plt.scatter(torch.sqrt(vol_elem).detach().numpy(), 1/(vol_elem_analycial).detach().numpy())

# %%
plt.scatter((vol_elem).detach().numpy(), 1/(vol_elem_analycial).detach().numpy())

# %%
from plotly3d.plot import scatter
scatter(z1)
# Out:
# <div>                            <div id="6684394f-3728-4590-a86e-7e4365709ef1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6684394f-3728-4590-a86e-7e4365709ef1")) {                    Plotly.newPlot(                        "6684394f-3728-4590-a86e-7e4365709ef1",                        [{"marker":{"color":0,"opacity":1,"size":1,"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"mode":"markers","name":"0.0","x":[0.20595650374889374,0.025039296597242355,-0.24767868220806122,0.2578166127204895,0.31454312801361084,-0.10809352248907089,-0.5742489099502563,0.2202124148607254,-0.08562542498111725,0.010151730850338936,0.09450021386146545,0.22819536924362183,-0.20770233869552612,0.08868219703435898,0.33109742403030396,-0.1223696619272232,0.006162953097373247,-0.2879212498664856,0.290976881980896,-0.6119368672370911,-0.28787633776664734,-0.20626522600650787,-0.23878750205039978,0.2461000382900238,0.3118334710597992,0.09244615584611893,-0.17480488121509552,-0.03170662373304367,0.13504435122013092,-0.15069414675235748,0.21302053332328796,0.07532277703285217,-0.4853963553905487,-0.133620947599411,0.24960821866989136,0.07030802220106125,0.3015698492527008,-0.03475232422351837,0.21878984570503235,0.201758474111557,-0.02245376445353031,0.25129419565200806,-0.0736660286784172,-0.0006439944263547659,0.06968101859092712,-0.15174555778503418,-0.10829181969165802,-0.19800496101379395,-0.3904058337211609,0.2216244488954544,0.25799065828323364,-0.016229217872023582,0.23238520324230194,-0.26734158396720886,-0.1303069144487381,-0.18703247606754303,0.1754411906003952,-0.12636049091815948,0.007772438693791628,-0.405842125415802,0.26628661155700684,-0.3353404402732849,0.3163466155529022,-0.5421032905578613,-0.3185184597969055,-0.2888529896736145,0.12325135618448257,0.14245761930942535,0.12828706204891205,-0.43370652198791504,0.24463671445846558,-0.0013329588109627366,0.20160600543022156,0.172271728515625,-0.2488197386264801,0.13628137111663818,-0.10140195488929749,-0.18511056900024414,-0.23929832875728607,0.1602931022644043,0.24911698698997498,0.10162964463233948,0.0704299658536911,-0.09365753084421158,-0.21947893500328064,-0.17949199676513672,0.12346354126930237,0.039687369018793106,0.21183794736862183,0.2963866889476776,0.21060681343078613,-0.2619435489177704,0.06448494642972946,-0.23474673926830292,0.2609774172306061,-0.058600105345249176,-0.13494972884655,-0.23480455577373505,0.2376091480255127,0.21057792007923126,-0.24125483632087708,-0.3568953275680542,-0.13117262721061707,0.3970288336277008,0.32143595814704895,-0.04294247180223465,0.014661801978945732,-0.25688835978507996,-0.08981500566005707,0.3129262328147888,-0.11298749595880508,-0.04106263443827629,-0.2571526765823364,0.059493668377399445,0.02135397121310234,-0.2438596487045288,-0.18654966354370117,0.1013839989900589,0.2633015811443329,0.08383338153362274,0.2779260277748108,0.13677330315113068,0.01810949482023716,-0.18765366077423096,0.3163837492465973,0.3692511320114136,0.10165321081876755,-0.04559943079948425,0.10535545647144318,0.17430463433265686,0.05838054418563843,-0.004569577984511852,0.12422855198383331,-0.22462321817874908,-0.24408376216888428,0.13823121786117554,-0.2746575176715851,-0.05557232350111008,0.27034249901771545,-0.29051363468170166,-0.22700895369052887,-0.2811460793018341,-0.6241885423660278,-0.12115027755498886,-0.27256596088409424,-0.21958225965499878,0.06393840163946152,-0.20851969718933105,-0.2506573796272278,0.1750372052192688,-0.11683086305856705,-0.20229622721672058,0.05210915952920914, ...

# %%
no_margin_mask = (x[:,0]>-1.5) & (x[:,0]<1.5) & (x[:,1]>-1.5) & (x[:,1]<1.5)
plt.scatter((vol_elem).detach().numpy()[no_margin_mask], (vol_elem_analycial).detach().numpy()[no_margin_mask])
plt.show()
plt.scatter(torch.log(vol_elem).detach().numpy()[no_margin_mask], torch.log(vol_elem_analycial).detach().numpy()[no_margin_mask])
plt.show()
plt.scatter(torch.sqrt(vol_elem).detach().numpy()[no_margin_mask], 1/(vol_elem_analycial).detach().numpy()[no_margin_mask])
plt.show()
plt.scatter((vol_elem).detach().numpy()[no_margin_mask], 1/(vol_elem_analycial).detach().numpy()[no_margin_mask])
plt.show()
