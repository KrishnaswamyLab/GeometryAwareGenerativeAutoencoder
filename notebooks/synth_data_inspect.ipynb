# %%
import numpy as np
import scprep

# %%
data = np.load("../synthetic_data/noisy_42_groups_17580_2000_3_0.2_0.2_all.npz")

# %%
data.files
# Out:
# ['data', 'colors', 'dist', 'phate', 'is_train']

# %%
scprep.plot.scatter2d(data['phate'], c=data['is_train'])
# Out:
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/.conda_envs/geosink/lib/python3.11/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: >
