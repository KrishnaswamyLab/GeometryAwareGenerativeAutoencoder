# %%
import numpy as np
import pathlib
import sys
sys.path.append('../../src')
from negative_sampling import add_negative_samples, make_hi_freq_noise
from diffusionmap import DiffusionMap
import phate
from plotly3d.plot import scatter

# %%
data = np.load("../../data/negative_sampling/hifreq1/hemisphere.npz")
scatter(data['data'], data['mask_x'])
# Out:
# <div>                            <div id="724d9297-233a-4416-a1ea-12396fcf137d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("724d9297-233a-4416-a1ea-12396fcf137d")) {                    Plotly.newPlot(                        "724d9297-233a-4416-a1ea-12396fcf137d",                        [{"marker":{"color":0,"opacity":1,"size":1,"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"mode":"markers","name":"0.0","x":[0.5275864349774495,0.1773498212102783,-1.1437345680996862,2.114696065340289,-0.006876845559510
# ...

# %%
data = np.load("../../data/negative_sampling/hifreq/hemisphere.npz")
scatter(data['data'], data['mask_x'])
# Out:
# <div>                            <div id="b11ddcf3-36b8-45de-96a6-65ca9e44e70c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b11ddcf3-36b8-45de-96a6-65ca9e44e70c")) {                    Plotly.newPlot(                        "b11ddcf3-36b8-45de-96a6-65ca9e44e70c",                        [{"marker":{"color":0,"opacity":1,"size":1,"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"mode":"markers","name":"0.0","x":[0.2913328373061227,0.6461370615042853,-0.5602806554594582,1.146960839210894,-0.204367113701356
# ...

# %%
data = np.load("../../data/negative_sampling/hifreq1noadd/hemisphere.npz")
scatter(data['data'], data['mask_x'])
# Out:
# <div>                            <div id="4e8f94c3-172d-43cf-bcd5-64388163213e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e8f94c3-172d-43cf-bcd5-64388163213e")) {                    Plotly.newPlot(                        "4e8f94c3-172d-43cf-bcd5-64388163213e",                        [{"marker":{"color":0,"opacity":1,"size":1,"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"mode":"markers","name":"0.0","x":[0.29531699708915843,-0.5859840503675088,-0.729317390800285,1.2096690326617436,0.24686283517730
# ...
