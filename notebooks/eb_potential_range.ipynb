# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
potential = np.load('../data/eb_hv_pca_subset_potential.npy')

# %%
potential.shape
# Out:
# (3000, 1873)

# %%
plt.hist(potential.flatten(), bins=100)
plt.show()
